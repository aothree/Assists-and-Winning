# %%
import pandas as pd
import numpy as np
import requests
import time
import re
import glob
import os

pd.options.display.max_columns = 999

# %% [markdown]
# ## Combine Historical Team Wins and Team Stats into one main dataframe `mdf`

# %%
def clean_team_name(my_string):
    if '*' in my_string:
        return my_string[:-5].strip()
    else:
        return my_string[:-4].strip()

# %%
def clean_team_name2(my_string):
    if '*' in my_string:
        return my_string[:-1].strip()
    else:
        return my_string.strip()

# %%
years = ['2022','2021', '2020', '2019', '2018','2017', '2016', '2015', '2014', '2013', '2012', '2011', 
         '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', 
         '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990',
        '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980']

for year in years:
    if year == '2022': 
        url = f'https://www.basketball-reference.com/leagues/NBA_{year}.html'
        res = requests.get(url)
        with open(f'./Data/html_files/NBA_{year}.xls', 'wb') as f:
            f.write(res.content)

        df = pd.read_html(f'./Data/html_files/NBA_{year}.xls')

        # get records 
        wins_df1 = pd.DataFrame(df[0]) 
        wins_df1.rename({'Eastern Conference': 'Team'}, axis = 1, inplace = True)
        wins_df1['Team'] = wins_df1['Team'].map(lambda x: clean_team_name(x))
        wins_df2 = pd.DataFrame(df[1]) 
        wins_df2.rename({'Western Conference': 'Team'}, axis = 1, inplace = True)
        wins_df2['Team'] = wins_df2['Team'].map(lambda x: clean_team_name(x))
        dfs = [wins_df1, wins_df2]
        wins_df = pd.concat(dfs, ignore_index = True)

        # get stats
        stats = pd.DataFrame(df[4]) 
        stats['Team'] = stats['Team'].map(lambda x: clean_team_name2(x))

        # merge and save to .csv
        df_merged = pd.merge(left = wins_df, right = stats, on = 'Team')
        df_merged['team_year'] = df_merged['Team'] + '_' + year
        df_merged['year'] = year
        df_merged.to_csv(f'./Data/yearly_stats/{year}_stats.csv')
        time.sleep(3)
    elif int(year) >2015 :
        url = f'https://www.basketball-reference.com/leagues/NBA_{year}.html'
        res = requests.get(url)
        with open(f'./Data/html_files/NBA_{year}.xls', 'wb') as f:
            f.write(res.content)

        df = pd.read_html(f'./Data/html_files/NBA_{year}.xls')

        # get records 
        wins_df1 = pd.DataFrame(df[0]) 
        wins_df1.rename({'Eastern Conference': 'Team'}, axis = 1, inplace = True)
        wins_df1['Team'] = wins_df1['Team'].map(lambda x: clean_team_name2(x))
        wins_df2 = pd.DataFrame(df[1]) 
        wins_df2.rename({'Western Conference': 'Team'}, axis = 1, inplace = True)
        wins_df2['Team'] = wins_df2['Team'].map(lambda x: clean_team_name2(x))
        dfs = [wins_df1, wins_df2]
        wins_df = pd.concat(dfs, ignore_index = True)

        # get stats
        stats = pd.DataFrame(df[4]) 
        stats['Team'] = stats['Team'].map(lambda x: clean_team_name2(x))

        # merge and save to .csv
        df_merged = pd.merge(left = wins_df, right = stats, on = 'Team')
        df_merged['team_year'] = df_merged['Team'] + '_' + year
        df_merged['year'] = year
        df_merged.to_csv(f'./Data/yearly_stats/{year}_stats.csv')
        time.sleep(3)
       
    else:
        print(f'scraping for {year}')
        url = f'https://www.basketball-reference.com/leagues/NBA_{year}.html'
        res = requests.get(url)
        with open(f'./Data/html_files/NBA_{year}.xls', 'wb') as f:
            f.write(res.content)

        df = pd.read_html(f'./Data/html_files/NBA_{year}.xls')

        # get records 
        wins_df1 = pd.DataFrame(df[0]) 
        wins_df1.rename({'Eastern Conference': 'Team'}, axis = 1, inplace = True)
        wins_df1['Team'] = wins_df1['Team'].map(lambda x: clean_team_name2(x))
        wins_df2 = pd.DataFrame(df[1]) 
        wins_df2.rename({'Western Conference': 'Team'}, axis = 1, inplace = True)
        wins_df2['Team'] = wins_df2['Team'].map(lambda x: clean_team_name2(x))
        dfs = [wins_df1, wins_df2]
        wins_df = pd.concat(dfs, ignore_index = True)

        # get stats
        stats = pd.DataFrame(df[3]) 
        stats['Team'] = stats['Team'].map(lambda x: clean_team_name2(x))

        # merge and save to .csv
        df_merged = pd.merge(left = wins_df, right = stats, on = 'Team')
        df_merged['team_year'] = df_merged['Team'] + '_' + year
        df_merged['year'] = year
        df_merged.to_csv(f'./Data/yearly_stats/{year}_stats.csv')
        time.sleep(3)
# Out:
# scraping for 2015
# scraping for 2014
# scraping for 2013
# scraping for 2012
# scraping for 2011
# scraping for 2010
# scraping for 2009
# scraping for 2008
# scraping for 2007
# scraping for 2006
# scraping for 2005
# scraping for 2004
# scraping for 2003
# scraping for 2002
# scraping for 2001
# scraping for 2000
# scraping for 1999
# scraping for 1998
# scraping for 1997
# scraping for 1996
# scraping for 1995
# scraping for 1994
# scraping for 1993
# scraping for 1992
# scraping for 1991
# scraping for 1990
# scraping for 1989
# scraping for 1988
# scraping for 1987
# scraping for 1986
# scraping for 1985
# scraping for 1984
# scraping for 1983
# scraping for 1982
# scraping for 1981
# scraping for 1980

# %%
wins_df.shape, stats.shape
# Out:
# ((26, 8), (23, 25))

# %%
stats
# Out:
#       Rk                    Team   G     MP    FG   FGA    FG%   3P  3PA  \
# 0    1.0           Atlanta Hawks  82  241.2  38.3  83.8  0.458  0.6  2.2
# 1    2.0  Portland Trail Blazers  82  241.2  40.8  85.5  0.478  0.7  2.3
# 2    3.0     Seattle SuperSonics  82  241.8  41.6  90.5  0.459  0.7  2.9
# 3    4.0      Philadelphia 76ers  82  242.1  42.0  92.2  0.455  0.9  3.4
# 4    5.0       Kansas City Kings  82  241.5  40.6  85.3  0.476  0.5  2.1
# 5    6.0          Boston Celtics  82  242.4  41.9  89.2  0.470  0.9  3.2
# 6    7.0         Milwaukee Bucks  82  241.5  42.1  91.3  0.462  0.9  3.7
# 7    8.0            Phoenix Suns  82  240.9  43.5  91.2  0.476  1.2  3.6
# 8    9.0   Golden State Warriors  82  242.4  41.9  85.1  0.493  0.9  2.7
# 9   10.0               Utah Jazz  82  241.5  43.4  87.6  0.496  0.8  2.6
# 10  11.0      Los Angeles Lakers  82  242.4  45.4  96.6  0.470  1.0  3.3
# 11  12.0         New Jersey Nets  82  241.5  42.4  90.6  0.469  0.7  2.5
# 12  13.0      Washington Bullets  82  242.4  44.1  94.8  0.465  0.7  2.6
# 19  0.278  44.5  89.0  0.501  24.0  31.2  0.770  15.8  29.7  45.4  26.1   9.9
# 20  0.277  46.2  92.1  0.502  22.7  29.3  0.773  16.1  31.4  47.5  28.1  10.7
# 21  0.306  47.7  94.0  0.507  21.1  27.8  0.758  15.2  30.1  45.4  30.9  10.1
# 22  0.280  42.9  87.9  0.488  21.3  27.8  0.764  15.1  29.9  44.9  25.8   9.4
#
#     BLK   TOV    PF    PTS
# 0   6.8  20.2  26.5  101.6
# 1   4.8  17.7  22.9  103.3
# 2   4.8  18.5  24.4  103.8
# 3   4.7  19.0  25.6  104.9
# 4   5.2  21.5  25.3  104.9
# 5   5.1  19.9  25.1  105.7
# 6   4.4  20.0  23.3  106.1
# 7   4.7  20.3  25.0  107.5
# 8   4.4  18.1  21.8  108.0
# 9   4.9  15.5  21.7  108.4
# 10  4.7  17.3  22.7  109.2
# 11  6.3  20.6  24.9  109.5
# 12  6.3  14.9  23.2  109.5
# 13  6.1  18.8  26.9  110.2
# 14  5.2  19.5  25.0  110.6
# 15  5.0  17.0  23.0  111.7
# 16  5.7  21.4  24.7  111.9
# 17  5.5  17.5  24.8  112.7
# 18  6.0  20.3  24.8  113.8
# 19  4.8  20.7  24.9  115.1
# 20  5.7  19.3  22.8  117.2
# 21  5.6  18.5  26.7  119.7
# 22  5.3  18.9  24.4  109.3

# %%
# check that both dfs have the team names in common.  should == 30
len(np.intersect1d(wins_df['Team'], stats['Team']))
# Out:
# 22

# %%
path = 'Data/yearly_stats' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))
all_files
# Out:
# ['Data/yearly_stats\\1980_stats.csv',
#  'Data/yearly_stats\\1981_stats.csv',
#  'Data/yearly_stats\\1982_stats.csv',
#  'Data/yearly_stats\\1983_stats.csv',
#  'Data/yearly_stats\\1984_stats.csv',
#  'Data/yearly_stats\\1985_stats.csv',
#  'Data/yearly_stats\\1986_stats.csv',
#  'Data/yearly_stats\\1987_stats.csv',
#  'Data/yearly_stats\\1988_stats.csv',
#  'Data/yearly_stats\\1989_stats.csv',
#  'Data/yearly_stats\\1990_stats.csv',
#  'Data/yearly_stats\\1991_stats.csv',
#  'Data/yearly_stats\\1992_stats.csv',
#  'Data/yearly_stats\\1993_stats.csv',
#  'Data/yearly_stats\\1994_stats.csv',
#  'Data/yearly_stats\\1995_stats.csv',
#  'Data/yearly_stats\\1996_stats.csv',
#  'Data/yearly_stats\\1997_stats.csv',
#  'Data/yearly_stats\\1998_stats.csv',
#  'Data/yearly_stats\\1999_stats.csv',
#  'Data/yearly_stats\\2000_stats.csv',
#  'Data/yearly_stats\\2001_stats.csv',
#  'Data/yearly_stats\\2002_stats.csv',
#  'Data/yearly_stats\\2003_stats.csv',
#  'Data/yearly_stats\\2004_stats.csv',
#  'Data/yearly_stats\\2005_stats.csv',
#  'Data/yearly_stats\\2006_stats.csv',
#  'Data/yearly_stats\\2007_stats.csv',
#  'Data/yearly_stats\\2008_stats.csv',
#  'Data/yearly_stats\\2009_stats.csv',
#  'Data/yearly_stats\\2010_stats.csv',
#  'Data/yearly_stats\\2011_stats.csv',
#  'Data/yearly_stats\\2012_stats.csv',
#  'Data/yearly_stats\\2013_stats.csv',
#  'Data/yearly_stats\\2014_stats.csv',
#  'Data/yearly_stats\\2015_stats.csv',
#  'Data/yearly_stats\\2016_stats.csv',
#  'Data/yearly_stats\\2017_stats.csv',
#  'Data/yearly_stats\\2018_stats.csv',
#  'Data/yearly_stats\\2019_stats.csv',
#  'Data/yearly_stats\\2020_stats.csv',
#  'Data/yearly_stats\\2021_stats.csv',
#  'Data/yearly_stats\\2022_stats.csv']

# %%
li = []
for file in all_files:
    df = pd.read_csv(file, index_col=None)
    li.append(df)

mdf = pd.concat(li, axis=0)
mdf.drop(columns = 'Unnamed: 0', inplace = True)
mdf.shape
# Out:
# (1194, 34)

# %%
mdf.head()
# Out:
#                  Team   W   L   W/L%    GB   PS/G   PA/G   SRS    Rk   G  \
# 0      Boston Celtics  61  21  0.744     —  113.5  105.7  7.37   6.0  82
# 1  Philadelphia 76ers  59  23  0.720   2.0  109.1  104.9  4.04   4.0  82
# 2  Washington Bullets  39  43  0.476  22.0  107.0  109.5 -2.27  13.0  82
# 3     New York Knicks  39  43  0.476  22.0  114.0  115.1 -0.96  20.0  82
# 4     New Jersey Nets  34  48  0.415  27.0  108.3  109.5 -0.98  12.0  82
#
#       MP    FG   FGA    FG%   3P  3PA    3P%    2P   2PA    2P%    FT   FTA  \
# 0  242.4  41.9  89.2  0.470  0.9  3.2  0.286  41.0  86.0  0.477  20.9  27.1
# 1  242.1  42.0  92.2  0.455  0.9  3.4  0.271  41.1  88.8  0.463  20.0  26.2
# 2  242.4  44.1  94.8  0.465  0.7  2.6  0.262  43.4  92.2  0.471  20.7  26.6
# 3  241.2  45.2  91.4  0.495  0.7  2.4  0.278  44.5  89.0  0.501  24.0  31.2
# 4  241.5  42.4  90.6  0.469  0.7  2.5  0.279  41.7  88.0  0.474  23.9  31.4
#
#      FT%   ORB   DRB   TRB   AST   STL  BLK   TOV    PF    PTS  \
# 0  0.770  14.2  28.0  42.2  22.8   8.4  5.1  19.9  25.1  105.7
# 1  0.765  16.1  28.7  44.8  25.5  10.7  4.7  19.0  25.6  104.9
# 2  0.777  14.6  32.6  47.2  25.9   9.0  6.3  14.9  23.2  109.5
# 3  0.770  15.8  29.7  45.4  26.1   9.9  4.8  20.7  24.9  115.1
# 4  0.761  15.7  31.7  47.3  26.7  10.4  6.3  20.6  24.9  109.5
#
#                  team_year  year
# 0      Boston Celtics_1980  1980
# 1  Philadelphia 76ers_1980  1980
# 2  Washington Bullets_1980  1980
# 3     New York Knicks_1980  1980
# 4     New Jersey Nets_1980  1980

# %%
mdf.to_csv('./Data/team_stats_1980_2022.csv')
